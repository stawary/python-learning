# %%
# %matplotlib inline
from pandas import Series
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data = Series([20,34,40,50,55,45,30],index=[1,2,3,4,5,6,7])
data
# Out:
# 1    20
# 2    34
# 3    40
# 4    50
# 5    55
# 6    45
# 7    30
# dtype: int64

# %% [markdown]
# # 折线图

# %% [markdown]
# plot绘图函数，参数:plot(X,Y)

# %%
X=data.index
Y=data.values
plt.plot(X,Y)

# %%
plt.plot(data)#data自身包含X(index)和Y(values)

# %%
t = np.arange(0.,4.,0.1) #range的numpy数组版，0到4间隔0.1
plt.plot(t,t,t,t+2,t,t**2)#注意学习此种写法，绘画在一张图(figure)里

# %%
plt.figure(figsize=(8,6))
x = np.arange(0.,20.,0.2)
plt.plot(x,np.sin(x),color='red',linestyle='-',linewidth=3,label='sin')#如何给两根曲线旁边列标签
plt.plot(x,np.cos(x),color='blue',linestyle='-',linewidth=3,label='cos')
plt.legend(loc='upper right')

# %% [markdown]
# # 散点图

# %%
plt.plot(X,Y,'o')

# %%
plt.scatter(X,Y) #scatter为散点图函数

# %% [markdown]
# # 柱状图

# %%
plt.bar(X,Y,color='r',width=0.5) #bar为柱状图函数
# Out:
# <Container object of 7 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 80像素/每英寸
plt.figure(figsize=(8, 6), dpi=80)
# 再创建一个规格为 1 x 1 的子图
plt.subplot(1, 1, 1)
# 柱子总数
N = 6
# 包含每个柱子对应值的序列
values = (25, 32, 34, 20, 41, 50)
# 包含每个柱子下标的序列
index = np.arange(N)
# 柱子的宽度
width = 0.35
# 绘制柱状图, 每根柱子的颜色为紫罗兰色
p2 = plt.bar(index, values, width, label="rainfall", color="#87CEFA")
# 设置横轴标签
plt.xlabel('Months')
# 设置纵轴标签
plt.ylabel('rainfall (mm)')
# 添加标题
plt.title('Monthly average rainfall')
# 添加纵横轴的刻度
plt.xticks(index, ('Jan', 'Fub', 'Mar', 'Apr', 'May', 'Jun'))
plt.yticks(np.arange(0, 81, 10))
# 添加图例
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # 绘图属性控制

# %% [markdown]
# ## 1、线条颜色和类型控制

# %%
plt.plot(X,Y,'g-.')

# %%
plt.plot(X,Y,'r-D')

# %% [markdown]
# 线条颜色、类型、标记符号的参数需一起放入参数，如'r-D': r表示线条颜色红色，-表示线条类型实线，s表示标记符号正方形(square)。
# 详细说明表格如下：

# %% [raw]
# 符号  颜色                线型  描述                 标记  描述
#  b    blue                 '-'  实线                 'o'    圆
#  g    green                '--' 虚线                 'v'   三角形
#  r    red                  '-.' 点划线               's'   正方形
#  c    cyan 蓝绿色          ':'  点线                 'p'   五边形
#  m    magenta 紫色                                   '*'   *
#  y    yellow                                         '+'   +
#  k    black                                          'D'   菱形
#  w    white

# %% [markdown]
# ## 2、加标题：图、横轴和纵轴

# %% [markdown]
# 关于matplotlib绘图中无法识别中文的问题，可以添加以下代码：

# %%
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
plt.plot(X,Y)
plt.title('月销量 ',fontsize=16) 
plt.xlabel('月份',fontsize=12)
plt.ylabel('销量',fontsize=12)
plt.show()

# %% [markdown]
# ## 3、其他属性

# %%
plt.figure(figsize=(8,6),dpi=100) #图画尺寸
t=np.arange(0.,4.,0.1)
plt.plot(t,t,color='red',linestyle='-',linewidth=3,label='Line1')
plt.plot(t,t+2,color='green',linestyle='',marker='*',linewidth=3,label='Line2')
plt.plot(t,t**2,color='blue',linestyle='--',marker='D',linewidth=3,label='Line3')
plt.legend(loc='upper left') #图标示例位置

# %% [markdown]
# # 多子图-subplots

# %%
plt.subplot(211)
plt.subplot(212)

# %%
plt.subplot(121)
plt.subplot(122)

# %%
data2 = Series([10,20,30,40,50,60,70],index=range(1,8))

plt.subplot(211)
plt.plot(data,'r-D')
plt.subplot(212)
plt.plot(data2,'g-D')
